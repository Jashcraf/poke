# %%
import numpy as np
import matplotlib.pyplot as plt
from poke.writing import read_serial_to_rayfront
from poke.poke_core import Rayfront
import poke.plotting as plot
import time
import poppy

# %%
# Use pre-generated rayfronts
ntrials = 10
nrays = 10
nrays_list = np.arange(10,110,nrays)
npix = 512
times = np.empty([ntrials,nrays])
rms = np.copy(times)

x = np.linspace(-2e-4,2e-4,npix)
x,y = np.meshgrid(x,x)
dcoords = np.array([x.ravel(),y.ravel(),np.zeros_like(x.ravel())])
timelist = []
rmslist = []

# load a rayfront
rf = read_serial_to_rayfront('sample_rayfront_gbd10rays.msgpack')

# %%
pix_meters = x[0,0]-x[0,1]
efl_hst = 57.6
pix_as = pix_meters/efl_hst*206265
airy_ref = poppy.misc.airy_2d(diameter=2.4,wavelength=rf.wavelength,shape=(512,512),pixelscale=pix_as)
airy_ref /= np.sum(airy_ref)
plt.imshow(np.log10(airy_ref))
pix_as
# Out:
# -0.002803122961513402

# %%
pix_LD = pix_meters/efl_hst * 2.4/551e-9
pix_LD*512
# Out:
# -30.3072276818644

# %%
np.save('airy_epd_2400mm_wlen_551nm_pixscale_2.8mas_npix_512.npy',airy_ref)

# %%
for i in range(ntrials):
    for j,nrays in enumerate(nrays_list):
        rf = read_serial_to_rayfront(f'sample_rayfront_gbd{nrays}rays.msgpack')
        t1 = time.perf_counter()
        field = rf.beamlet_decomposition_field(dcoords,dnorms=np.array([0,1,0]),misaligned=True,memory_avail=8)
        times[i,j] = (time.perf_counter()-t1)
        irrad = np.abs(field)**2
        irrad /= np.sum(irrad)
        rms[i,j] = (np.std(airy_ref-irrad.reshape([npix,npix])))
# Out:
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.2549711670144461
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.4708575000113342
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.2762830419960665
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.838110707991291
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.78343962499639
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 6.012787917003152
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 11.96408550000342
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.004954792006174
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.099291624996113
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 16.045951417007018
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.119917749994784
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.24100270899362
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 16.05441508399963
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 22.309295791987097
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.5727211670018733
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.438863458999549
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 12.60286295900005
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 18.007449500000803
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 21.861156333994586
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 26.03427649999503
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.013187457996537
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 9.868797916991753
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 15.217433999991044
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 20.780901207996067
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 26.363156541992794
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 31.97089091700036
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 37.47584345799987
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 37.55703149999317
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.9250010420073522
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 9.90019095900061
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 15.66249595899717
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 21.1839934590098
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 27.087077917007264
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 32.64181804200052
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 38.07753316700109
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 44.03224191699701
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 49.84927874999994
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.25745337500120513
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.3073921659961343
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.01528849999886
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.716254166996805
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.49847329199838
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.931473541990272
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 12.925930916986545
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.651472540994291
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.808346874997369
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 16.65093520798837
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.348211749995244
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.54510333298822
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 16.790618749990244
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 22.745897582994075
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.712611665992881
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.56338649999816
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.40196166599344
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.27026691599167
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 19.164362499999697
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 23.048669374999008
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.117544292006642
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 9.009231333999196
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 13.456207292008912
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 18.036628500005463
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 23.959481416997733
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 29.53802533399721
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 34.099276125009055
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 34.18504533400119
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 4.0002148329949705
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.096432416001335
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.23938199999975
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.446033375003026
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 20.68475283299631
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 24.950769582996145
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 29.24337020800158
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 35.03186279100191
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 39.78166525000415
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.24012541699630674
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2631660839979304
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.029987959002028
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.7101099169958616
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.469487084003049
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.249306625002646
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 10.481046917004278
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.06271529100195
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.000199916001293
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 14.522394083003746
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.220861417008564
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.361343958007637
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 15.243909708005958
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 19.791643000004115
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.731558833998861
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.46854808399803
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.192724916996667
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.086175624994212
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 18.87509383399447
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 22.595177124996553
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 3.977072124995175
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 8.260659084000508
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 12.542195999994874
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 16.835235374994227
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 21.1464750419982
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 25.443969291998656
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 29.803425083999173
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 29.886182749993168
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.8717964999959804
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.078526416997192
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.246221333989524
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.467545708990656
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 20.56792274999316
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 24.68537504199776
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 28.813337458996102
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 32.916061541996896
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 37.04851112500182
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.24484725001093466
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2505673339910572
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.004024291993119
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.684396666008979
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.403137833010987
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.255596916991635
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 10.497381958004553
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.083044416009216
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 8.96560620800301
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 13.417680458005634
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.2310685830016155
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 9.92116787499981
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 14.430918624988408
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 19.48899437500222
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.6903675829962594
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.5918614999973215
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.36689233299694
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.088386582996463
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 18.82893283299927
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 22.58282045798842
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 3.9986246670014225
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 8.179803542006994
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 12.34215445900918
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 18.280401000010897
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 23.896013750010752
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 29.8734766250127
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 35.59716216700326
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 35.68914291700639
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 4.010221666991129
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.25460149999708
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.586906791999354
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.92826045799302
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 21.35330904199509
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 25.73254229199665
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 30.01870745800261
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 34.38306962499337
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 38.93104187499557
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.2580320830020355
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.380254582996713
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.096667416000855
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 3.067574207991129
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 6.028283499996178
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.69245558300463
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 11.673599332993035
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.2751719590014545
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.341058709003846
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 16.440309792000335
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.2724535840097815
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.690629917007755
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 16.760912167010247
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 22.98961354199855
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.727141625000513
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.567079666987411
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.3681807499961
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.246403666998958
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 19.12662274998729
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 23.11617979199218
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.165021875000093
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 8.781941292007104
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 13.758501958000124
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 18.63329391699517
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 23.754352292002295
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 28.17997316700348
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 32.68929283300531
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 32.78855729200586
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.9793271249945974
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.287531957990723
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.541479415987851
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.8363859999954
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 21.15889008299564
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 25.678607582987752
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 30.28703654099081
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 34.71896212499996
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 39.02033520799887
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.24739491600485053
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2914035840076394
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.042995499999961
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.775464082995313
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.5534037920006085
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.385206124992692
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 11.196125082991784
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.476063416004763
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.560538040997926
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 16.6404955409962
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.816108875005739
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 11.465679917004309
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 17.375585709000006
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 23.743897417007247
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.7533959580032388
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.547126042001764
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.321277249997365
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.095205958001316
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 19.05518816699623
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 23.162564750004094
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.155299999998533
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 8.877380042002187
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 13.40886458400928
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 17.914669000005233
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 22.470347375012352
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 27.014666292001493
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 31.56230995900114
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 31.663704792008502
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.978814791989862
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.13116320798872
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.256112207993283
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.36439629198867
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 20.495926957999473
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 24.60977324999112
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 28.715092749989708
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 32.9697135000024
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 37.10622516699368
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.24927675000799354
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.3157884169922909
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.0439789170050062
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.821947292002733
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.666497166996123
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.42480391600111
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 10.711577916008537
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.118337541993242
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.00190562500211
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 14.631916708996869
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.362446041996009
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.681950124999275
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 16.707626000003074
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 22.90748533299484
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.7584686250047525
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.551697792005143
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.714176250010496
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 16.06701325000904
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 20.153396749999956
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 24.287209708010778
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.1706585840001935
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 10.0661299170024
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 14.556812541995896
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 20.198475666999002
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 24.763248083996587
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 29.02787449999596
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 33.42753287499363
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 33.51162504199601
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.91824283299502
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 7.904837541995221
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 11.899400458001764
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 15.8685829580063
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 19.871447041994543
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 23.87380891700741
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 28.386227124996367
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 32.90000824999879
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 37.22442862500611
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.2633694999967702
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2929899580049096
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.092504625004949
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.916984625000623
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 6.035989124997286
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.798467041007825
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 11.021829958001035
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.138099542004056
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 9.466355333002866
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 14.098575249998248
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.442023124996922
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.845455999995465
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 17.017033582989825
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 23.383329958000104
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.6823818330012728
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 7.542006250005215
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 11.310454500009655
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 15.065605042007519
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 18.847623417008435
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 22.760491750013898
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.124595541012241
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 8.54917754100461
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 13.125138750008773
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 17.666451750003034
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 22.1735374580021
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 26.69233350000286
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 31.256314250000287
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 31.343383833009284
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 3.9947276250022696
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.246838708000723
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.528934333007783
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 16.757866416010074
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 21.01332349999575
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 25.257565499996417
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 30.71965933300089
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 34.87677145800262
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 38.96165816600842
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.2466744999983348
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2849186249950435
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.065201250006794
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.7867980000009993
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.565440332997241
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.3879007500072476
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 10.717852500005392
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.180037791011273
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.113801041006809
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 14.624388291005744
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.365601958998013
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 9.632568624991109
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 14.344278666991158
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 19.176332624992938
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 3.996839874991565
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 8.31683399999747
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 12.41269937499601
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 16.3883941660024
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 20.712328665991663
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 25.087907082997845
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.325285416998668
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 10.063790708998567
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 14.435109750003903
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 18.89005654200446
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 23.39132279199839
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 27.937512417003745
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 32.46840208399226
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 32.55635666700255
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 4.005240875005256
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.336206583000603
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 13.241483125006198
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 17.52419304101204
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 21.84768404100032
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 26.138155958004063
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 30.44408841599943
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 34.722831916005816
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 39.078196375005064
# pixels =  65536
# rays =  60
# beamlet field at wavelength = 5.51e-07
# computeunit =  60
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [-2.11058023e-17 -1.69822200e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 60)
# loop 2 completed, time elapsed = 0.2532634160015732
# pixels =  65536
# rays =  276
# beamlet field at wavelength = 5.51e-07
# computeunit =  276
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [8.42755063e-17 8.40895027e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 276)
# loop 2 completed, time elapsed = 1.2958382090000669
# pixels =  65536
# rays =  648
# beamlet field at wavelength = 5.51e-07
# computeunit =  648
# override nloops =  1
# (3, 65536)
# (3,)
# centroid at =  [1.32368035e-17 1.25416090e-17 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 648)
# loop 2 completed, time elapsed = 3.0351945419970434
# pixels =  65536
# rays =  1184
# beamlet field at wavelength = 5.51e-07
# computeunit =  592
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-3.77709848e-17 -3.82520537e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 592)
# loop 0 completed, time elapsed = 2.7451300420070766
# phi shape =  (65536, 592)
# loop 1 completed, time elapsed = 5.521178709008382
# pixels =  65536
# rays =  1876
# beamlet field at wavelength = 5.51e-07
# computeunit =  938
# override nloops =  2
# (3, 65536)
# (3,)
# centroid at =  [-2.74236109e-17 -2.83340865e-17  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 938)
# loop 0 completed, time elapsed = 4.538860250002472
# phi shape =  (65536, 938)
# loop 1 completed, time elapsed = 11.010452832997544
# pixels =  65536
# rays =  2724
# beamlet field at wavelength = 5.51e-07
# computeunit =  908
# override nloops =  3
# (3, 65536)
# (3,)
# centroid at =  [1.61150692e-18 1.50286780e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 908)
# loop 0 completed, time elapsed = 4.115437333006412
# phi shape =  (65536, 908)
# loop 1 completed, time elapsed = 10.210725625001942
# phi shape =  (65536, 908)
# loop 2 completed, time elapsed = 15.61556108300283
# pixels =  65536
# rays =  3720
# beamlet field at wavelength = 5.51e-07
# computeunit =  930
# override nloops =  4
# (3, 65536)
# (3,)
# centroid at =  [9.36798038e-18 9.90814331e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 930)
# loop 0 completed, time elapsed = 4.349385625013383
# phi shape =  (65536, 930)
# loop 1 completed, time elapsed = 10.72279083300964
# phi shape =  (65536, 930)
# loop 2 completed, time elapsed = 17.023301375011215
# phi shape =  (65536, 930)
# loop 3 completed, time elapsed = 23.16672079100681
# pixels =  65536
# rays =  4872
# beamlet field at wavelength = 5.51e-07
# computeunit =  812
# override nloops =  6
# (3, 65536)
# (3,)
# centroid at =  [-6.86421036e-18 -7.13758363e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 812)
# loop 0 completed, time elapsed = 4.011250374998781
# phi shape =  (65536, 812)
# loop 1 completed, time elapsed = 8.475609999994049
# phi shape =  (65536, 812)
# loop 2 completed, time elapsed = 12.98729908298992
# phi shape =  (65536, 812)
# loop 3 completed, time elapsed = 17.363056292000692
# phi shape =  (65536, 812)
# loop 4 completed, time elapsed = 21.6241085419897
# phi shape =  (65536, 812)
# loop 5 completed, time elapsed = 26.924571957992157
# pixels =  65536
# rays =  6180
# beamlet field at wavelength = 5.51e-07
# computeunit =  882
# override nloops =  8
# (3, 65536)
# (3,)
# centroid at =  [9.50576667e-18 9.19458924e-18 0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 882)
# loop 0 completed, time elapsed = 4.167114958007005
# phi shape =  (65536, 882)
# loop 1 completed, time elapsed = 10.298930791002931
# phi shape =  (65536, 882)
# loop 2 completed, time elapsed = 15.819616500011762
# phi shape =  (65536, 882)
# loop 3 completed, time elapsed = 20.53464787499979
# phi shape =  (65536, 882)
# loop 4 completed, time elapsed = 25.301319500009413
# phi shape =  (65536, 882)
# loop 5 completed, time elapsed = 30.220861833004165
# phi shape =  (65536, 882)
# loop 6 completed, time elapsed = 34.8576698750112
# phi shape =  (65536, 6)
# loop 7 completed, time elapsed = 34.94581541600928
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  852
# override nloops =  9
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 852)
# loop 0 completed, time elapsed = 4.12181050000072
# phi shape =  (65536, 852)
# loop 1 completed, time elapsed = 8.36677583301207
# phi shape =  (65536, 852)
# loop 2 completed, time elapsed = 12.82059700001264
# phi shape =  (65536, 852)
# loop 3 completed, time elapsed = 17.18283175000397
# phi shape =  (65536, 852)
# loop 4 completed, time elapsed = 21.617455708008492
# phi shape =  (65536, 852)
# loop 5 completed, time elapsed = 25.99114779100637
# phi shape =  (65536, 852)
# loop 6 completed, time elapsed = 30.417179875003058
# phi shape =  (65536, 852)
# loop 7 completed, time elapsed = 34.84685004100902
# phi shape =  (65536, 852)
# loop 8 completed, time elapsed = 39.231769250007346

# %%
np.save('runtimes_new_cpu_10.npy',times)
np.save('rms_new_cpu_10.npy',rms)

# %%
plt.style.use('bmh')
plt.figure(figsize=[6,5])
plt.title('GBD Runtime v.s. Nrays across Pupil')
plt.errorbar(nrays_list,np.array(np.mean(times,axis=0)),np.array(np.std(times,axis=0)),linestyle='dotted',color='black')
plt.scatter(nrays_list,np.array(np.mean(times,axis=0)),c=np.log10(np.mean(rms,axis=0)),cmap='inferno',s=150)
plt.colorbar(label='Log10 RMS difference to Airy')
plt.ylabel('Runtime [s]',fontsize=12)
plt.xlabel('Nrays across pupil',fontsize=12)
plt.show()

# %%
plt.style.use('bmh')
plt.figure(figsize=[20,5])
plt.subplot(131)
plt.title('GBD PSF N=100')
plt.imshow(np.log10(irrad.reshape([256,256])))
plt.xticks([0],[''])
plt.yticks([0],[''])
plt.colorbar(fraction=0.04)
plt.subplot(132)
plt.title('Fractional Difference to Airy')
plt.imshow((airy_ref-irrad.reshape([256,256]))/airy_ref,cmap='RdBu_r',vmin=-1,vmax=1)
plt.colorbar()
plt.xticks([0],[''])
plt.yticks([0],[''])
plt.subplot(133)
plt.title('GBD Runtime v.s. Nrays across Pupil')
plt.scatter(nrays_list,timelist,c=np.log10(rmslist),cmap='inferno',s=150)
plt.colorbar(label='Log10 RMS difference to Airy')
plt.ylabel('Runtime [s]',fontsize=12)
plt.xlabel('Nrays across pupil',fontsize=12)
plt.show()

# %%
np.save('runtimes_gbd_weber.npy',timelist)

# %%
field = rf.beamlet_decomposition_field(dcoords,dnorms=np.array([0,1,0]))
# Out:
# pixels =  65536
# rays =  7668
# beamlet field at wavelength = 5.51e-07
# computeunit =  451
# override nloops =  18
# (3, 65536)
# (3,)
# centroid at =  [-7.52091379e-18 -7.79478690e-18  0.00000000e+00]
# centroid offset applied
# phi shape =  (65536, 451)
# loop 0 completed, time elapsed = 3.869765083999937
# phi shape =  (65536, 451)
# loop 1 completed, time elapsed = 7.794634249999945
# phi shape =  (65536, 451)
# loop 2 completed, time elapsed = 11.634672166999962
# phi shape =  (65536, 451)
# loop 3 completed, time elapsed = 15.108829541999967
# phi shape =  (65536, 451)
# loop 4 completed, time elapsed = 19.003410583999994
# phi shape =  (65536, 451)
# loop 5 completed, time elapsed = 22.602738584000008
# phi shape =  (65536, 451)
# loop 6 completed, time elapsed = 26.396467167000083
# phi shape =  (65536, 451)
# loop 7 completed, time elapsed = 29.887257625000075
# phi shape =  (65536, 451)
# loop 8 completed, time elapsed = 33.430172000000084
# phi shape =  (65536, 451)
# loop 9 completed, time elapsed = 36.70811954200008
# phi shape =  (65536, 451)
# loop 10 completed, time elapsed = 40.4363679170001
# phi shape =  (65536, 451)
# loop 11 completed, time elapsed = 43.77420591700002
# phi shape =  (65536, 451)
# loop 12 completed, time elapsed = 47.12249075
# phi shape =  (65536, 451)
# loop 13 completed, time elapsed = 50.48094508400004
# phi shape =  (65536, 451)
# loop 14 completed, time elapsed = 53.84885633399995
# phi shape =  (65536, 451)
# loop 15 completed, time elapsed = 57.31831624999995
# phi shape =  (65536, 451)
# loop 16 completed, time elapsed = 60.596221000000014
# phi shape =  (65536, 1)
# loop 17 completed, time elapsed = 60.63982137499988
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f386d75ac6f8> in <module>
#       1 field = rf.beamlet_decomposition_field(dcoords,dnorms=np.array([0,1,0]))
# ----> 2 plt.imshow(np.log10(np.abs(field.reshape([64,64]))))
#
# ValueError: cannot reshape array of size 65536 into shape (64,64)

# %%
plt.imshow(np.log10(np.abs(field.reshape([256,256]))))
