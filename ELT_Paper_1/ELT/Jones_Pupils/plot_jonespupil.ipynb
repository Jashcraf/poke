# %%
fig1 = plt.figure(figsize=(17, 6))

ax1 = fig1.add_subplot(241)
im1=ax1.imshow(np.abs(Exx_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title('$Axx$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(242)
im1=ax1.imshow(np.abs(Exy_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title('$Axy$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(243)
im1=ax1.imshow(np.angle(Exx_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title(r'$\phi xx$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(244)
im1=ax1.imshow(np.angle(Exy_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title(r'$\phi xy$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(245)
im1=ax1.imshow(np.abs(Eyx_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title('$Ayx$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(246)
im1=ax1.imshow(np.abs(Eyy_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title('$Ayy$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(247)
im1=ax1.imshow(np.angle(Eyx_array),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title(r'$\phi yx$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)

ax1 = fig1.add_subplot(248)
im1=ax1.imshow(np.angle(Eyy_array)-(np.pi),cmap='viridis',interpolation='nearest',extent=[np.min(px),np.max(px),np.min(py),np.max(py)])
ax1.yaxis.set_ticks_position('both')
ax1.xaxis.set_ticks_position('both')
ax1.minorticks_on()
ax1.tick_params(which='both', direction='in', width=0.5, labelsize=12)
ax1.set_ylabel('py', fontsize=12)
ax1.set_xlabel('px', fontsize=12)
ax1.set_title(r'$\phi yy$',fontdict={'fontsize': 20, 'fontweight': 'medium'})
cb = fig1.colorbar(im1,orientation='vertical',shrink=0.7)
cb.ax.tick_params(labelsize=14)
fig1.subplots_adjust(hspace=0.4, wspace=0.2, top=0.95, right=0.95)
#fig1.savefig('D:\\Work\\OneDrive\\University_Arizona\\Polarization_aberrations_ELTs\\GMT\\Figures\\Jones_pupil_V_band.png',format='png', bbox_inches='tight')
